# %% [markdown]
# #Write a Python program to take two numbers as input from the user and display their sum.

# %%
num1=int(input("enter first number"))
num2=int(input("enter 2nd number"))
sum=num1+num2
print(sum)
# Out:
# enter first number30
# enter 2nd number50
# 80

# %% [markdown]
# #Calculate and print the midpoint of two numbers entered by the user.

# %%
num1=int(input("enter first number"))
num2=int(input("enter 2nd number"))
mid=(num1+num2)/2
print(mid)
# Out:
# enter first number15
# enter 2nd number20
# 17.5

# %% [markdown]
# #Write a Python program to calculate the area of a triangle using the formula: area = 0.5 * base * height.

# %%
base=int(input("enter base :"))
height=int(input("enter height :"))
area=0.5*base*height
(area)
# Out:
# enter base :15
# enter height :20
# 150.0

# %% [markdown]
# #Take three numbers as input from the user and display their product.

# %%
a=int(input("enter the first value: "))
b=int(input("enter the 2nd value :"))
c=int(input("enter the 3rd value :"))
product=a*b*c
print("the product is =", product)
# Out:
# enter the first value: 23
# enter the 2nd value :45
# enter the 3rd value :45
# the product is = 46575

# %% [markdown]
# #Take a number as input and display its square and cube

# %%
a=int(input("enter the number :"))
square=a**2
cube=a**3
print("square of the product",square)
print("cube of the product",cube)
# Out:
# enter the number :3
# square of the product 9
# cube of the product 27

# %% [markdown]
# #Take two numbers as input and display their quotient and remainder.

# %%
num1 =int(input("enter the no. :"))
num2 =int(input("enter the 2nd no. :"))
quotient=num1 /num2
remainder= num1 % num2
print("the quotient of the given no. :",quotient)
print("the remainder of the given no.:",remainder)
# Out:
# enter the no. :23
# enter the 2nd no. :45
# the quotient of the given no. : 0.5111111111111111
# the remainder of the given no.: 23

# %% [markdown]
# #Take three numbers as input and display their average.

# %%
a=int(input("enter the first value:"))
b=int(input("enter the 2nd value:"))
c=int(input("enter the 3rd value"))
average=(a+b+c)/3
print("the given number average is :",average)
# Out:
# enter the first value:23
# enter the 2nd value:52
# enter the 3rd value45
# the given number average is : 40.0

# %% [markdown]
# #8.	Write a Python program to calculate the area of a rectangle using the formula: area = length * width.

# %%
length=int(input("enter the given number :"))
width=int(input("enter the given numeber :"))
area=length*width
print("the area of the rectangle",area)
# Out:
# enter the given number :25
# enter the given numeber :12
# the area of the rectangle 300

# %% [markdown]
# #9.	Take five numbers as input representing marks obtained and total marks Display the percentage.

# %%
a=int(input("enter the first value :"))
b=int(input("enter the 2nd value :"))
c=int(input("enter the 3rd value :"))
d=int(input("enter the 4th value :"))
e=int(input("enter the 5th value :"))
total=a+b+c+d+e
percentage=(total/500)*100
print("the percentage of student",percentage)
# Out:
# enter the first value :99
# enter the 2nd value :89
# enter the 3rd value :94
# enter the 4th value :85
# enter the 5th value :96
# the percentage of student 92.60000000000001
