# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
    def info(self):
        print("print the car make", self.make, "print the model", self.model, "print the year", self.year)

# %%
A=Car("toyota","camry",2022)

# %%
print( A.info())
# Out:
# print the car make toyota print the model camry print the year 2022
# None

# %% [markdown]
# Question 5: Define a class named Circle with attributes radius and color. Include methods to calculate the area and circumference of the circle. Create an instance of the Circle class with radius 5 and color "blue", then print its area and circumference.

# %%
class Circle:
  def __init__(self,radius,color):
    self.radius=radius
    self.color=color

    def area(self):
     print("Area of Circle",3.14*self.radius*self.radius)
    def circumference(self):
     print("Circumference of Circle",2*3.14*self.radius)

# %%
A=Circle(5,"red")

# %%
A.circumference()
# Out:
# Circumference of Circle 31.400000000000002

# %%
A.area()
# Out:
# Area of Circle 78.5

# %% [markdown]
# Question 6: Create a class named Book with attributes title, author, and price. Include a method called discount() that takes a percentage discount as an argument and updates the price accordingly. Create an instance of the Book class and call the discount() method with a 20% discount.

# %%
class Book:
    def __init__(self,title,author,price):
        self.title=title
        self.author=author
        self.price=price
    def discount(self,percentage):
        discount_price=(percentage/100) * self.price
        new_price=self.price-discount_price
        print("price of discount",new_price)

# %%
book1=Book("Chhava","Shivaji Sawant",550)

# %%
book1.discount(20)
# Out:
# price of discount 440.0

# %% [markdown]
# Question 7: Define a class called Student with attributes name, age, and grades. Include a method called calculate_average() that computes the average grade of the student. Create an instance of the Student class with name "Alice", age 20, and grades [90, 85, 88], then print the average grade.

# %%
class Student:
    def __init__(self,name,age,grades):
        self.name=name
        self.age=age
        self.grades=grades
    def calculate_average(self,average):
        average=sum(self.grades)/len(self.grades)
        print("name of student",self.name,"age of the student",self.age,"average grade of student",average)

# %%
std1=Student("Alice",20,[90,85,88])

# %%
std1.calculate_average("average")
# Out:
# name of student Alice age of the student 20 average grade of student 87.66666666666667

# %% [markdown]
# Question 8: Create a class named Rectangle with attributes length and width. Include methods to calculate the area, perimeter, and diagonal of the rectangle. Create an instance of the Rectangle class with length 4 and width 3, then print its area, perimeter, and diagonal.

# %%
class Rectangle:
  def __init__(self,length,width):
      self.length=length
      self.width=width

  def area_rectangle(self,area):
      area=self.length*self.width
      print("area of rectangle",area)

  def perimeter_rectangle(self,perimeter):
      perimeter=(self.length+self.width)*2
      print("perimeter of rectangle",perimeter)

  def diagonal_rectangle(self,diagonal):
      diagonal=(self.length**2+self.width**2)**0.5
      print("diagonal of rectangle",diagonal)

# %%
rect1=Rectangle(4,3)

# %%
rect1.area_rectangle("area of rectangle=")
# Out:
# area of rectangle 12

# %%
rect1.perimeter_rectangle("perimeter of rectangle=")
# Out:
# perimeter of rectangle 14

# %%
rect1.diagonal_rectangle("diagonal of rectangle")
# Out:
# diagonal of rectangle 5.0
